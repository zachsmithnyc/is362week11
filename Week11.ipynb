# %%
from pynytimes import NYTAPI
import pandas as pd 
import json

nyt = NYTAPI("fuONl8sZwDhKtjJJa21s5qbhzIBEeLy5", parse_dates=True)
books = nyt.best_sellers_list()
df = pd.json_normalize(books)
df
# Out:
#     rank  rank_last_week  weeks_on_list  asterisk  dagger primary_isbn10  \
# 0      1               0              1         0       0     0593422422
# 1      2              10             40         0       0     1501171356
# 2      3               3             23         0       0     038554734X
# 3      4               0              1         0       0     1538704390
# 4      5               2             96         0       0     1501110365
# 5      6               1             26         0       0     1668001225
# 6      7               0              1         0       0     1982180064
# 7      8               5             93         0       0     1501161938
# 8      9              11              5         0       0     0593243749
# 9     10               4             15         0       0     1524798649
# 10    11               8             71         0       0     1538724731
# 11    12               9              7         0       0     1335004882
# ...

# %%
df[['rank', 'title', 'author']]
# Out:
#     rank                                 title  \
# 0      1                            DARK ANGEL
# 1      2             THE LAST THING HE TOLD ME
# 2      3                  LESSONS IN CHEMISTRY
# 3      4                           YOURS TRULY
# 4      5                       IT ENDS WITH US
# 5      6                     IT STARTS WITH US
# 6      7                              LASSITER
# 7      8     THE SEVEN HUSBANDS OF EVELYN HUGO
# 8      9                       HELLO BEAUTIFUL
# 9     10                 DAISY JONES & THE SIX
# 10    11                                VERITY
# 11    12                           NEVER NEVER
# 12    13                    THE ONLY SURVIVORS
# 13    14  TOMORROW, AND TOMORROW, AND TOMORROW
# 14    15                         HANG THE MOON
#
#                               author
# 0                      John Sandford
# 1                         Laura Dave
# 2                      Bonnie Garmus
# 3                         Ab Jimenez
# ...
